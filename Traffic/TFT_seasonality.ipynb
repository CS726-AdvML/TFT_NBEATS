# %%
# !git clone https://github.com/CS726-AdvML/long_range_TSF.git
# Out:
# Cloning into 'long_range_TSF'...
# remote: Enumerating objects: 340, done.
# remote: Counting objects: 100% (340/340), done.
# remote: Compressing objects: 100% (246/246), done.
# remote: Total 340 (delta 69), reused 325 (delta 56), pack-reused 0
# Receiving objects: 100% (340/340), 19.63 MiB | 5.58 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
cd /content/long_range_TSF/TFT_NBEATS
# Out:
# /content/long_range_TSF/TFT_NBEATS

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp -R /content/gdrive/Shareddrives/CS726-Advanced-Machine-Learning/tft_outputs /content/long_range_TSF

# %%
# !set -e

# !pip3 install virtualenv # Assumes pip3 is installed!
# !python3 -m virtualenv $OUTPUT_FOLDER/venv
# !source $OUTPUT_FOLDER/venv/bin/activate
# !pip3 install --pre "tensorflow==1.15.*"
# !pip3 install -r requirements.txt

# !python3 -m script_download_data traffic ./tft_outputs

# %%
# !chmod 777 run.sh
# !./run.sh
# !rm -r /content/drive/Shareddrives/CS726-Advanced-Machine-Learning/tft_tf2-master/tft_outputs/saved_models/traffic/fixed

# %%
# !python3 script_train_fixed_params.py "traffic" "./tft_outputs" "no" "yes"

# %%
from script_train_fixed_params import main
import os

import data_formatters.electricity
import data_formatters.favorita
import data_formatters.traffic
import data_formatters.volatility

import argparse
import datetime as dte
import os

import data_formatters.base
import expt_settings.configs
import libs.hyperparam_opt
import libs.tft_model
import libs.utils as utils
import numpy as np
import pandas as pd
import tensorflow.compat.v1 as tf

ExperimentConfig = expt_settings.configs.ExperimentConfig
HyperparamOptManager = libs.hyperparam_opt.HyperparamOptManager
ModelClass = libs.tft_model.TemporalFusionTransformer
tf.experimental.output_all_intermediates(True)


expt_name = "traffic"
use_gpu = True
model_folder = "/content/long_range_TSF/tft_outputs/saved_models/traffic/fixed"
data_csv_path = "/content/long_range_TSF/tft_outputs/data/traffic/hourly_data.csv"
data_formatter = data_formatters.traffic.TrafficFormatter()
use_testing_mode = False

num_repeats = 1

if not isinstance(data_formatter, data_formatters.base.GenericDataFormatter):
    raise ValueError(
        "Data formatters should inherit from" +
        "AbstractDataFormatter! Type={}".format(type(data_formatter)))

# Tensorflow setup
default_keras_session = tf.keras.backend.get_session()

if use_gpu:
    tf_config = utils.get_default_tensorflow_config(tf_device="gpu", gpu_id=0)

else:
    tf_config = utils.get_default_tensorflow_config(tf_device="cpu")

print("*** Training from defined parameters for {} ***".format(expt_name))

print("Loading & splitting data...")
raw_data = pd.read_csv(data_csv_path, index_col=0)
train, valid, test = data_formatter.split_data(raw_data)
train_samples, valid_samples = data_formatter.get_num_samples_for_calibration()
print("reached here")
# Sets up default params
fixed_params = data_formatter.get_experiment_params()
params = data_formatter.get_default_model_params()
params["model_folder"] = model_folder

# Parameter overrides for testing only! Small sizes used to speed up script.
train_samples, valid_samples = 20000, 2000
if use_testing_mode:
    fixed_params["num_epochs"] = 1
    params["hidden_layer_size"] = 6
    train_samples, valid_samples = 100, 10
# Sets up hyperparam manager
print("*** Loading hyperparm manager ***")
opt_manager = HyperparamOptManager({k: [params[k]] for k in params},
                                    fixed_params, model_folder)

# Training -- one iteration only
print("*** Running calibration ***")
print("Params Selected:")
print(fixed_params)

for k in params:
    print("{}: {}".format(k, params[k]))

print(train_samples)

best_loss = np.Inf
for _ in range(num_repeats):

    tf.reset_default_graph()
    with tf.Graph().as_default(), tf.Session(config=tf_config) as sess:

        tf.keras.backend.set_session(sess)

        params = opt_manager.get_next_parameters()
        model = ModelClass(params, use_cudnn=use_gpu)
        if not model.training_data_cached():
            model.cache_batched_data(train, "train", num_samples=train_samples)
            model.cache_batched_data(valid, "valid", num_samples=valid_samples)

        sess.run(tf.global_variables_initializer())
        model.fit()

        val_loss = model.evaluate()

        if val_loss < best_loss:
            opt_manager.update_score(params, val_loss, model)
            best_loss = val_loss

        tf.keras.backend.set_session(default_keras_session)
# Out:
# Selecting GPU ID=0
# *** Training from defined parameters for traffic ***
# Loading & splitting data...
# Formatting train-valid-test splits.
# Setting scalers with training data...
# reached here
# *** Loading hyperparm manager ***
# *** Running calibration ***
# Params Selected:
# {'total_time_steps': 192, 'num_encoder_steps': 168, 'num_epochs': 100, 'early_stopping_patience': 5, 'multiprocessing_workers': 6, 'column_definition': [('id', <DataTypes.REAL_VALUED: 0>, <InputTypes.ID: 4>), ('hours_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.TIME: 5>), ('values', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('time_on_day', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('day_of_week', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('hours_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('categorical_id', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)], 'input_size': 5, 'output_size': 1, 'category_counts': [963], 'input_obs_loc': [0], 'static_input_loc': [4], 'known_regular_inputs': [1, 2, 3], 'known_categorical_inputs': [0]}
# dropout_rate: 0.3
# hidden_layer_size: 320
# learning_rate: 0.001
# minibatch_size: 128
# max_gradient_norm: 100.0
# num_heads: 4
# stack_size: 1
# model_folder: /content/long_range_TSF/tft_outputs/saved_models/traffic/fixed
# 20000
# Resetting temp folder...
# *** TemporalFusionTransformer params ***
# # dropout_rate = 0.3
# # hidden_layer_size = 320
# # learning_rate = 0.001
# # max_gradient_norm = 100.0
# # minibatch_size = 128
# # model_folder = /content/long_range_TSF/tft_outputs/saved_models/traffic/fixed
# # num_heads = 4
# # stack_size = 1
# # total_time_steps = 192
# # num_encoder_steps = 168
# # num_epochs = 100
# # early_stopping_patience = 5
# # multiprocessing_workers = 6
# # column_definition = [('id', <DataTypes.REAL_VALUED: 0>, <InputTypes.ID: 4>), ('hours_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.TIME: 5>), ('values', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('time_on_day', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('day_of_week', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('hours_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('categorical_id', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)]
# # input_size = 5
# # output_size = 1
# # category_counts = [963]
# # input_obs_loc = [0]
# # static_input_loc = [4]
# # known_regular_inputs = [1, 2, 3]
# # known_categorical_inputs = [0]
# get tft embeddings
# WARNING:tensorflow:From /content/long_range_TSF/TFT_NBEATS/libs/tft_model.py:934: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# hello
# I am sesonal layer layer
# 320
# seasonality!!!!!!!!!!!!!!!!!!!!!
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 5)]     0           []
#
#  tf_op_layer_TemporalFusionTran  [(None, 192, 1)]    0           ['input_1[0][0]']
#  sformer/strided_slice_1 (Tenso
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 192)]       0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_2 (Tenso                                  former/strided_slice_1[0][0]']
#  rFlowOpLayer)
#
#  sequential (Sequential)        (None, 192, 320)     308160      ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_2[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 320)]       0           ['sequential[0][0]']
#  sformer/strided_slice_3 (Tenso
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 320)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/stack (TensorFlowOpLay                                  former/strided_slice_3[0][0]']
#  er)
#
#  flatten (Flatten)              (None, 320)          0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/stack[0][0]']
#
#  dense_5 (Dense)                (None, 320)          102720      ['flatten[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 320)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_11 (Tens                                  former/stack[0][0]']
#  orFlowOpLayer)
#
#  activation (Activation)        (None, 320)          0           ['dense_5[0][0]']
#
#  dense_9 (Dense)                (None, 1, 320)       102720      ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_11[0][0]']
#
#  dense_6 (Dense)                (None, 320)          102720      ['activation[0][0]']
#
#  activation_2 (Activation)      (None, 1, 320)       0           ['dense_9[0][0]']
#
#  dropout (Dropout)              (None, 320)          0           ['dense_6[0][0]']
#
#  dense_10 (Dense)               (None, 1, 320)       102720      ['activation_2[0][0]']
#
#  dense_7 (Dense)                (None, 1)            321         ['dropout[0][0]']
#
#  dense_8 (Dense)                (None, 1)            321         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 1, 320)       0           ['dense_10[0][0]']
#
#  dense_4 (Dense)                (None, 1)            321         ['flatten[0][0]']
#
#  multiply (Multiply)            (None, 1)            0           ['dense_7[0][0]',
#                                                                   'dense_8[0][0]']
#
#  dense_11 (Dense)               (None, 1, 320)       102720      ['dropout_1[0][0]']
#
#  dense_12 (Dense)               (None, 1, 320)       102720      ['dropout_1[0][0]']
#
#  add (Add)                      (None, 1)            0           ['dense_4[0][0]',
#                                                                   'multiply[0][0]']
#
#  multiply_1 (Multiply)          (None, 1, 320)       0           ['dense_11[0][0]',
#                                                                   'dense_12[0][0]']
#
#  layer_normalization (LayerNorm  (None, 1)           2           ['add[0][0]']
#  alization)
#
#  add_1 (Add)                    (None, 1, 320)       0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_11[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  activation_1 (Activation)      (None, 1)            0           ['layer_normalization[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 1, 320)      640         ['add_1[0][0]']
#  rmalization)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 1)]      0           ['activation_1[0][0]']
#  sformer/ExpandDims (TensorFlow
#  OpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 320)]    0           ['layer_normalization_1[0][0]']
#  sformer/concat_1/concat (Tenso
#  rFlowOpLayer)
#
#  multiply_2 (Multiply)          (None, 1, 320)       0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/ExpandDims[0][0]',
#                                                                   'tf_op_layer_TemporalFusionTrans
#                                                                  former/concat_1/concat[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 320)]       0           ['multiply_2[0][0]']
#  sformer/Sum (TensorFlowOpLayer
#  )
#
#  dense_13 (Dense)               (None, 320)          102720      ['tf_op_layer_TemporalFusionTrans
#                                                                  former/Sum[0][0]']
#
#  activation_3 (Activation)      (None, 320)          0           ['dense_13[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 192, 4)]    0           ['input_1[0][0]']
#  sformer/strided_slice (TensorF
#  lowOpLayer)
#
#  dense_14 (Dense)               (None, 320)          102720      ['activation_3[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 192, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_5 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 192, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_6 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 192, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_7 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 192, 1)]    0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_4 (Tenso                                  former/strided_slice[0][0]']
#  rFlowOpLayer)
#
#  dropout_2 (Dropout)            (None, 320)          0           ['dense_14[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 192, 320)    640         ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_5[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 192, 320)    640         ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_6[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 192, 320)    640         ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/strided_slice_7[0][0]']
#
#  time_distributed (TimeDistribu  (None, 192, 320)    640         ['tf_op_layer_TemporalFusionTrans
#  ted)                                                            former/strided_slice_4[0][0]']
#
#  dense_15 (Dense)               (None, 320)          102720      ['dropout_2[0][0]']
#
#  dense_16 (Dense)               (None, 320)          102720      ['dropout_2[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 192, 320, 3  0          ['time_distributed_1[0][0]',
#  sformer/stack_2 (TensorFlowOpL  )]                               'time_distributed_2[0][0]',
#  ayer)                                                            'time_distributed_3[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 192, 320, 1  0          ['time_distributed[0][0]']
#  sformer/stack_1 (TensorFlowOpL  )]
#  ayer)
#
#  multiply_3 (Multiply)          (None, 320)          0           ['dense_15[0][0]',
#                                                                   'dense_16[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 168, 320, 3  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_8 (Tenso  )]                              former/stack_2[0][0]']
#  rFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 168, 320, 1  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_9 (Tenso  )]                              former/stack_1[0][0]']
#  rFlowOpLayer)
#
#  add_2 (Add)                    (None, 320)          0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/Sum[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 168, 320, 4  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/concat (TensorFlowOpLa  )]                              former/strided_slice_8[0][0]',
#  yer)                                                             'tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_9[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 320)         640         ['add_2[0][0]']
#  rmalization)
#
#  tf_op_layer_TemporalFusionTran  [(None, 168, 1280)]  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/Reshape (TensorFlowOpL                                  former/concat[0][0]']
#  ayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 320)]    0           ['layer_normalization_2[0][0]']
#  sformer/ExpandDims_1 (TensorFl
#  owOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 24, 320, 3)  0          ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_10 (Tens  ]                               former/stack_2[0][0]']
#  orFlowOpLayer)
#
#  time_distributed_5 (TimeDistri  (None, 168, 320)    409920      ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/Reshape[0][0]']
#
#  time_distributed_6 (TimeDistri  (None, 1, 320)      102400      ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/ExpandDims_1[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 24, 960)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/Reshape_1 (TensorFlowO                                  former/strided_slice_10[0][0]']
#  pLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 1, 320)]    0           ['layer_normalization_2[0][0]']
#  sformer/ExpandDims_3 (TensorFl
#  owOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 168, 320)]  0           ['time_distributed_5[0][0]',
#  sformer/add_6 (TensorFlowOpLay                                   'time_distributed_6[0][0]']
#  er)
#
#  tf_op_layer_TemporalFusionTran  [(None, 168, 320)]  0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_12 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 168, 320)]  0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_13 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 168, 320)]  0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_14 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 168, 320)]  0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_15 (Tens                                  former/concat[0][0]']
#  orFlowOpLayer)
#
#  time_distributed_27 (TimeDistr  (None, 24, 320)     307520      ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/Reshape_1[0][0]']
#
#  time_distributed_28 (TimeDistr  (None, 1, 320)      102400      ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/ExpandDims_3[0][0]']
#
#  activation_7 (Activation)      (None, 168, 320)     0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/add_6[0][0]']
#
#  time_distributed_10 (TimeDistr  (None, 168, 320)    102720      ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_12[0][0]']
#
#  time_distributed_14 (TimeDistr  (None, 168, 320)    102720      ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_13[0][0]']
#
#  time_distributed_18 (TimeDistr  (None, 168, 320)    102720      ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_14[0][0]']
#
#  time_distributed_22 (TimeDistr  (None, 168, 320)    102720      ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_15[0][0]']
#
#  tf_op_layer_TemporalFusionTran  [(None, 24, 320)]   0           ['time_distributed_27[0][0]',
#  sformer/add_11 (TensorFlowOpLa                                   'time_distributed_28[0][0]']
#  yer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 24, 320)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_16 (Tens                                  former/strided_slice_10[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 24, 320)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_17 (Tens                                  former/strided_slice_10[0][0]']
#  orFlowOpLayer)
#
#  tf_op_layer_TemporalFusionTran  [(None, 24, 320)]   0           ['tf_op_layer_TemporalFusionTrans
#  sformer/strided_slice_18 (Tens                                  former/strided_slice_10[0][0]']
#  orFlowOpLayer)
#
#  time_distributed_7 (TimeDistri  (None, 168, 320)    102720      ['activation_7[0][0]']
#  buted)
#
#  activation_9 (Activation)      (None, 168, 320)     0           ['time_distributed_10[0][0]']
#
#  activation_10 (Activation)     (None, 168, 320)     0           ['time_distributed_14[0][0]']
#
#  activation_11 (Activation)     (None, 168, 320)     0           ['time_distributed_18[0][0]']
#
#  activation_12 (Activation)     (None, 168, 320)     0           ['time_distributed_22[0][0]']
#
#  activation_13 (Activation)     (None, 24, 320)      0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/add_11[0][0]']
#
#  time_distributed_32 (TimeDistr  (None, 24, 320)     102720      ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_16[0][0]']
#
#  time_distributed_36 (TimeDistr  (None, 24, 320)     102720      ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_17[0][0]']
#
#  time_distributed_40 (TimeDistr  (None, 24, 320)     102720      ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/strided_slice_18[0][0]']
#
#  dropout_6 (Dropout)            (None, 168, 320)     0           ['time_distributed_7[0][0]']
#
#  time_distributed_11 (TimeDistr  (None, 168, 320)    102720      ['activation_9[0][0]']
#  ibuted)
#
#  time_distributed_15 (TimeDistr  (None, 168, 320)    102720      ['activation_10[0][0]']
#  ibuted)
#
#  time_distributed_19 (TimeDistr  (None, 168, 320)    102720      ['activation_11[0][0]']
#  ibuted)
#
#  time_distributed_23 (TimeDistr  (None, 168, 320)    102720      ['activation_12[0][0]']
#  ibuted)
#
#  time_distributed_29 (TimeDistr  (None, 24, 320)     102720      ['activation_13[0][0]']
#  ibuted)
#
#  activation_15 (Activation)     (None, 24, 320)      0           ['time_distributed_32[0][0]']
#
#  activation_16 (Activation)     (None, 24, 320)      0           ['time_distributed_36[0][0]']
#
#  activation_17 (Activation)     (None, 24, 320)      0           ['time_distributed_40[0][0]']
#
#  time_distributed_8 (TimeDistri  (None, 168, 4)      1284        ['dropout_6[0][0]']
#  buted)
#
#  time_distributed_9 (TimeDistri  (None, 168, 4)      1284        ['dropout_6[0][0]']
#  buted)
#
#  dropout_7 (Dropout)            (None, 168, 320)     0           ['time_distributed_11[0][0]']
#
#  dropout_8 (Dropout)            (None, 168, 320)     0           ['time_distributed_15[0][0]']
#
#  dropout_9 (Dropout)            (None, 168, 320)     0           ['time_distributed_19[0][0]']
#
#  dropout_10 (Dropout)           (None, 168, 320)     0           ['time_distributed_23[0][0]']
#
#  dense_21 (Dense)               (None, 320)          102720      ['tf_op_layer_TemporalFusionTrans
#                                                                  former/Sum[0][0]']
#
#  dense_25 (Dense)               (None, 320)          102720      ['tf_op_layer_TemporalFusionTrans
#                                                                  former/Sum[0][0]']
#
#  dropout_11 (Dropout)           (None, 24, 320)      0           ['time_distributed_29[0][0]']
#
#  time_distributed_33 (TimeDistr  (None, 24, 320)     102720      ['activation_15[0][0]']
#  ibuted)
#
#  time_distributed_37 (TimeDistr  (None, 24, 320)     102720      ['activation_16[0][0]']
#  ibuted)
#
#  time_distributed_41 (TimeDistr  (None, 24, 320)     102720      ['activation_17[0][0]']
#  ibuted)
#
#  time_distributed_4 (TimeDistri  (None, 168, 4)      5124        ['tf_op_layer_TemporalFusionTrans
#  buted)                                                          former/Reshape[0][0]']
#
#  multiply_7 (Multiply)          (None, 168, 4)       0           ['time_distributed_8[0][0]',
#                                                                   'time_distributed_9[0][0]']
#
#  time_distributed_12 (TimeDistr  (None, 168, 320)    102720      ['dropout_7[0][0]']
#  ibuted)
#
#  time_distributed_13 (TimeDistr  (None, 168, 320)    102720      ['dropout_7[0][0]']
#  ibuted)
#
#  time_distributed_16 (TimeDistr  (None, 168, 320)    102720      ['dropout_8[0][0]']
#  ibuted)
#
#  time_distributed_17 (TimeDistr  (None, 168, 320)    102720      ['dropout_8[0][0]']
#  ibuted)
#
#  time_distributed_20 (TimeDistr  (None, 168, 320)    102720      ['dropout_9[0][0]']
#  ibuted)
#
#  time_distributed_21 (TimeDistr  (None, 168, 320)    102720      ['dropout_9[0][0]']
#  ibuted)
#
#  time_distributed_24 (TimeDistr  (None, 168, 320)    102720      ['dropout_10[0][0]']
#  ibuted)
#
#  time_distributed_25 (TimeDistr  (None, 168, 320)    102720      ['dropout_10[0][0]']
#  ibuted)
#
#  activation_5 (Activation)      (None, 320)          0           ['dense_21[0][0]']
#
#  activation_6 (Activation)      (None, 320)          0           ['dense_25[0][0]']
#
#  time_distributed_30 (TimeDistr  (None, 24, 3)       963         ['dropout_11[0][0]']
#  ibuted)
#
#  time_distributed_31 (TimeDistr  (None, 24, 3)       963         ['dropout_11[0][0]']
#  ibuted)
#
#  dropout_12 (Dropout)           (None, 24, 320)      0           ['time_distributed_33[0][0]']
#
#  dropout_13 (Dropout)           (None, 24, 320)      0           ['time_distributed_37[0][0]']
#
#  dropout_14 (Dropout)           (None, 24, 320)      0           ['time_distributed_41[0][0]']
#
#  add_6 (Add)                    (None, 168, 4)       0           ['time_distributed_4[0][0]',
#                                                                   'multiply_7[0][0]']
#
#  multiply_8 (Multiply)          (None, 168, 320)     0           ['time_distributed_12[0][0]',
#                                                                   'time_distributed_13[0][0]']
#
#  multiply_9 (Multiply)          (None, 168, 320)     0           ['time_distributed_16[0][0]',
#                                                                   'time_distributed_17[0][0]']
#
#  multiply_10 (Multiply)         (None, 168, 320)     0           ['time_distributed_20[0][0]',
#                                                                   'time_distributed_21[0][0]']
#
#  multiply_11 (Multiply)         (None, 168, 320)     0           ['time_distributed_24[0][0]',
#                                                                   'time_distributed_25[0][0]']
#
#  dense_22 (Dense)               (None, 320)          102720      ['activation_5[0][0]']
#
#  dense_26 (Dense)               (None, 320)          102720      ['activation_6[0][0]']
#
#  time_distributed_26 (TimeDistr  (None, 24, 3)       2883        ['tf_op_layer_TemporalFusionTrans
#  ibuted)                                                         former/Reshape_1[0][0]']
#
#  multiply_13 (Multiply)         (None, 24, 3)        0           ['time_distributed_30[0][0]',
#                                                                   'time_distributed_31[0][0]']
#
#  time_distributed_34 (TimeDistr  (None, 24, 320)     102720      ['dropout_12[0][0]']
#  ibuted)
#
#  time_distributed_35 (TimeDistr  (None, 24, 320)     102720      ['dropout_12[0][0]']
#  ibuted)
#
#  time_distributed_38 (TimeDistr  (None, 24, 320)     102720      ['dropout_13[0][0]']
#  ibuted)
#
#  time_distributed_39 (TimeDistr  (None, 24, 320)     102720      ['dropout_13[0][0]']
#  ibuted)
#
#  time_distributed_42 (TimeDistr  (None, 24, 320)     102720      ['dropout_14[0][0]']
#  ibuted)
#
#  time_distributed_43 (TimeDistr  (None, 24, 320)     102720      ['dropout_14[0][0]']
#  ibuted)
#
#  layer_normalization_6 (LayerNo  (None, 168, 4)      8           ['add_6[0][0]']
#  rmalization)
#
#  add_7 (Add)                    (None, 168, 320)     0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_12[0][0]',
#                                                                   'multiply_8[0][0]']
#
#  add_8 (Add)                    (None, 168, 320)     0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_13[0][0]',
#                                                                   'multiply_9[0][0]']
#
#  add_9 (Add)                    (None, 168, 320)     0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_14[0][0]',
#                                                                   'multiply_10[0][0]']
#
#  add_10 (Add)                   (None, 168, 320)     0           ['tf_op_layer_TemporalFusionTrans
#                                                                  former/strided_slice_15[0][0]',
#                                                                   'multiply_11[0][0]']
#
#  dropout_4 (Dropout)            (None, 320)          0           ['dense_22[0][0]']
#
#  dropout_5 (Dropout)            (None, 320)          0           ['dense_26[0][0]']
#
#  add_11 (Add)                   (None, 24, 3)        0           ['time_distributed_26[0][0]',
#                                                                   'multiply_13[0][0]']
#
#  multiply_14 (Multiply)         (None, 24, 320)      0           ['time_distributed_34[0][0]',
#                                                                   'time_distributed_35[0][0]']
#
#  multiply_15 (Multiply)         (None, 24, 320)      0           ['time_distributed_38[0][0]',
#                                                                   'time_distributed_39[0][0]']
#
#  multiply_16 (Multiply)         (None, 24, 320)      0           ['time_distributed_42[0][0]',
#                                                                   'time_distributed_43[0][0]']
#
#  activation_8 (Activation)      (None, 168, 4)       0           ['layer_normalization_6[0][0]']
# ...
# Getting locations for 401078
# Getting locations for 401079
# Getting locations for 401083
# Getting locations for 401084
# Getting locations for 401085
# Getting locations for 401086
# Getting locations for 401090
# Getting locations for 401091
# Getting locations for 401094
# Getting locations for 401095
# Getting locations for 401097
# Getting locations for 401098
# Getting locations for 401100
# Getting locations for 401102
# Getting locations for 401103
# Getting locations for 401104
# Getting locations for 401106
# Getting locations for 401107
# Getting locations for 401110
# Getting locations for 401111
# Getting locations for 401112
# Getting locations for 401113
# Getting locations for 401114
# Getting locations for 401118
# Getting locations for 401121
# Getting locations for 401124
# Getting locations for 401126
# Getting locations for 401129
# Getting locations for 401134
# Getting locations for 401137
# Getting locations for 401141
# Getting locations for 401142
# Getting locations for 401143
# Getting locations for 401144
# Getting locations for 401148
# Getting locations for 401151
# Getting locations for 401152
# Getting locations for 401154
# Getting locations for 401793
# Getting locations for 401794
# Getting locations for 401796
# Getting locations for 401797
# Getting locations for 401798
# Getting locations for 401799
# Getting locations for 401800
# Getting locations for 401801
# Getting locations for 401802
# Getting locations for 401808
# Getting locations for 401809
# Getting locations for 401810
# Getting locations for 401811
# Getting locations for 401816
# Getting locations for 401817
# Getting locations for 401818
# Getting locations for 401820
# Getting locations for 401825
# Getting locations for 401826
# Getting locations for 401829
# Getting locations for 401830
# Getting locations for 401831
# Getting locations for 401832
# Getting locations for 401833
# Getting locations for 401834
# Getting locations for 401835
# Getting locations for 401837
# Getting locations for 401838
# Getting locations for 401839
# Getting locations for 401840
# Getting locations for 401842
# Getting locations for 401844
# Getting locations for 401846
# Getting locations for 401851
# Getting locations for 401852
# Getting locations for 401853
# Getting locations for 401856
# Getting locations for 401857
# Getting locations for 401860
# Getting locations for 401868
# Getting locations for 401870
# Getting locations for 401871
# Getting locations for 401872
# Getting locations for 401873
# Getting locations for 401875
# Getting locations for 401877
# Getting locations for 401878
# Getting locations for 401879
# Getting locations for 401881
# Getting locations for 401882
# Getting locations for 401883
# Getting locations for 401888
# Getting locations for 401889
# Getting locations for 401894
# Getting locations for 401898
# Getting locations for 401899
# Getting locations for 401900
# Getting locations for 401901
# Getting locations for 401908
# Getting locations for 401910
# Getting locations for 401911
# Getting locations for 401913
# Getting locations for 401914
# Getting locations for 401917
# Getting locations for 401918
# Getting locations for 401923
# Getting locations for 401924
# Getting locations for 401925
# Getting locations for 401926
# Getting locations for 401927
# Getting locations for 401928
# Getting locations for 401929
# Getting locations for 401934
# Getting locations for 401935
# Getting locations for 401936
# Getting locations for 401937
# Getting locations for 401942
# Getting locations for 401943
# Getting locations for 401950
# Getting locations for 401951
# Getting locations for 401954
# Getting locations for 401955
# Getting locations for 401956
# Getting locations for 401957
# Getting locations for 401958
# Getting locations for 401994
# Getting locations for 401996
# Getting locations for 401997
# Getting locations for 401998
# Getting locations for 402002
# Getting locations for 402003
# Getting locations for 402006
# Getting locations for 402008
# Getting locations for 402018
# Getting locations for 402027
# Getting locations for 402030
# Getting locations for 402032
# Getting locations for 402042
# Getting locations for 402045
# Getting locations for 402046
# Getting locations for 402048
# Getting locations for 402049
# Getting locations for 402050
# Getting locations for 402051
# Getting locations for 402052
# Getting locations for 402053
# Getting locations for 402054
# Getting locations for 402055
# Getting locations for 402056
# Getting locations for 402060
# Getting locations for 402061
# Getting locations for 402062
# Getting locations for 402067
# Getting locations for 402068
# Getting locations for 402069
# Getting locations for 402070
# Getting locations for 402071
# Getting locations for 402072
# Getting locations for 402077
# Getting locations for 402081
# Getting locations for 402082
# Getting locations for 402083
# Getting locations for 402084
# Getting locations for 402085
# Getting locations for 402086
# Getting locations for 402087
# Getting locations for 402088
# Getting locations for 402089
# Getting locations for 402090
# Extracting 2000 samples...
# Cached data "valid" updated
# *** Fitting TemporalFusionTransformer ***
# fitting function
# Getting batched_data
# Using cached training data
# Using cached validation data
# Using keras standard fit
# Train on 20000 samples, validate on 2000 samples
# Epoch 1/100
# 20000/20000 [==============================] - ETA: 0s - loss: 3.1414
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 20000/20000 [==============================] - 101s 5ms/sample - loss: 3.1414 - val_loss: 1.0531
# Epoch 2/100
# 20000/20000 [==============================] - 88s 4ms/sample - loss: 0.7692 - val_loss: 0.5370
# Epoch 3/100
# 20000/20000 [==============================] - 90s 4ms/sample - loss: 0.7034 - val_loss: 0.5231
# Epoch 4/100
# 20000/20000 [==============================] - 90s 5ms/sample - loss: 0.7114 - val_loss: 0.6422
# Epoch 5/100
# 20000/20000 [==============================] - 91s 5ms/sample - loss: 0.4984 - val_loss: 0.3951
# Epoch 6/100
# 20000/20000 [==============================] - 91s 5ms/sample - loss: 0.5148 - val_loss: 0.7231
# Epoch 7/100
# 20000/20000 [==============================] - 90s 5ms/sample - loss: 0.4763 - val_loss: 0.9474
# Epoch 8/100
# 20000/20000 [==============================] - 91s 5ms/sample - loss: 0.4162 - val_loss: 0.2773
# Epoch 9/100
# 20000/20000 [==============================] - 91s 5ms/sample - loss: 0.4007 - val_loss: 0.3817
# Epoch 10/100
# 20000/20000 [==============================] - 90s 5ms/sample - loss: 0.3718 - val_loss: 0.3324
# Epoch 11/100
# 20000/20000 [==============================] - 91s 5ms/sample - loss: 0.3528 - val_loss: 0.3002
# Epoch 12/100
# 20000/20000 [==============================] - 90s 5ms/sample - loss: 0.3498 - val_loss: 0.3803
# Epoch 13/100
# 20000/20000 [==============================] - 91s 5ms/sample - loss: 0.3499 - val_loss: 0.2629
# Epoch 14/100
# 20000/20000 [==============================] - 91s 5ms/sample - loss: 0.3107 - val_loss: 0.2310
# Epoch 15/100
# 20000/20000 [==============================] - 91s 5ms/sample - loss: 0.3408 - val_loss: 0.3332
# Epoch 16/100
# 20000/20000 [==============================] - 90s 5ms/sample - loss: 0.3566 - val_loss: 0.2810
# Epoch 17/100
# 20000/20000 [==============================] - 90s 5ms/sample - loss: 0.4063 - val_loss: 0.4837
# Epoch 18/100
# 20000/20000 [==============================] - 90s 5ms/sample - loss: 0.4853 - val_loss: 0.7422
# Epoch 19/100
# 20000/20000 [==============================] - 90s 5ms/sample - loss: 0.4214 - val_loss: 0.5500
# Cannot load from /content/long_range_TSF/tft_outputs/saved_models/traffic/fixed/tmp, skipping ...
# Using cached validation data
# Optimal model found, updating
# Model saved to: /content/long_range_TSF/tft_outputs/saved_models/traffic/fixed/TemporalFusionTransformer.ckpt

# %%
print("*** Running tests ***")
# import data_formatters.electricity
# import data_formatters.favorita
# import data_formatters.traffic
# import data_formatters.volatility

# import argparse
# import datetime as dte
# import os

# import data_formatters.base

tf.reset_default_graph()
with tf.Graph().as_default(), tf.Session(config=tf_config) as sess:
    tf.keras.backend.set_session(sess)
    best_params = opt_manager.get_best_params()
    model = ModelClass(best_params, use_cudnn=use_gpu)

    model.load(opt_manager.hyperparam_folder)

    print("Computing best validation loss")
    val_loss = model.evaluate(valid)
    print("Validation loss is : ", val_loss)
    print("Computing test loss")
    output_map = model.predict(test, return_targets=True)
    print(type(output_map))
    print(output_map.keys())
    targets = data_formatter.format_predictions(output_map["targets"])
    p50_forecast = data_formatter.format_predictions(output_map["p50"])
    p90_forecast = data_formatter.format_predictions(output_map["p90"])

    def extract_numerical_data(data):
        """Strips out forecast time and identifier columns."""
        return data[[
            col for col in data.columns
            if col not in {"forecast_time", "identifier"}
        ]]

    p50_loss = utils.numpy_normalised_quantile_loss(
        extract_numerical_data(targets), extract_numerical_data(p50_forecast),
        0.5)
    p90_loss = utils.numpy_normalised_quantile_loss(
        extract_numerical_data(targets), extract_numerical_data(p90_forecast),
        0.9)

    tf.keras.backend.set_session(default_keras_session)

print("Training completed @ {}".format(dte.datetime.now()))
print("Best validation loss = {}".format(val_loss))
print("Params:")

for k in best_params:
    print(k, " = ", best_params[k])
print()
print("Normalised Quantile Loss for Test Data: P50={}, P90={}".format(
    p50_loss.mean(), p90_loss.mean()))
# Out:
# Streaming output truncated to the last 5000 lines.
#   5.65313036e-03 -8.87625851e-03  1.25488103e-03 -2.99428147e-03
#   4.47175838e-03  9.39134602e-03  3.11085070e-03 -7.22593861e-03
#  -9.95781086e-03  1.12478365e-03  2.48575304e-03  6.59938110e-03
#  -6.26833597e-03  1.95916183e-03  6.03592722e-03  5.58471540e-03
#  -1.39214797e-04  9.85062961e-03  6.15863642e-03 -1.62969641e-02
#   1.04135042e-02 -2.06106878e-03 -8.18346068e-03  4.71199863e-03
#   4.85354103e-03 -8.90843663e-03  4.28510085e-03 -6.19142177e-03
#   6.18509762e-03 -8.46149400e-03 -1.12781823e-02 -1.22270342e-02
#  -1.03922216e-02  1.10306330e-02  2.44902866e-03 -7.54901627e-03
#  -8.49777274e-03 -9.63522960e-03 -2.82401149e-03  2.34503229e-03
#  -1.03920046e-03 -4.12816927e-03 -9.11900494e-03 -9.07842349e-03
#   4.35612258e-03  2.40617199e-03  3.99016077e-03 -7.96977337e-03
#   4.24432475e-03 -3.76863568e-03 -1.74389649e-02 -4.23554156e-04
#  -1.01151625e-02 -6.39506616e-03 -6.23299554e-03  2.62569939e-03
#  -7.25094881e-03 -7.75661413e-03 -6.77791703e-03 -1.03136906e-02
#  -1.95911410e-03  3.98855656e-03  6.38841977e-03  4.09977540e-04
#  -3.55386245e-03 -7.22895376e-04 -1.99807668e-03 -1.07480697e-02
#   4.34968807e-03 -3.62495007e-03  4.16123867e-03 -1.60897488e-03
#  -1.34941870e-02 -9.86591098e-04 -5.04541583e-03  7.28636282e-03
#   3.24667199e-03  4.90325736e-03  7.11393077e-03  2.80807377e-03
#   7.74750765e-03  9.95962415e-03  1.38155115e-03 -4.26207623e-03
#   3.96458578e-04 -9.23797395e-03  5.56294387e-03 -7.10423943e-03
#  -8.67898110e-03  6.28137495e-03  1.04764896e-03 -7.75327487e-03
#   2.37547350e-03  2.78783916e-03  4.88933583e-04  9.58757382e-03
#   1.26704089e-02  6.29864261e-03 -4.42179106e-03 -2.45989719e-03
#   3.25503759e-03  9.12173931e-03  9.45898239e-03 -5.44940587e-03
#   2.52365530e-03  6.24874095e-03 -5.91279007e-03  1.01684136e-02
#   3.90636688e-03 -1.80741912e-03 -5.96327335e-03  3.10381828e-03
#  [ 0.1211923  -0.09388059 -0.04538691 ...  0.06658936  0.04135678
#   -0.07375222]
#  [-0.02373121 -0.07365284 -0.01895142 ... -0.06778894 -0.09335133
#    0.05366369]]
# tensor: TemporalFusionTransformer/time_distributed_8/bias (float32) [4]
# [ 0.0068299   0.00492147 -0.00754668  0.00601749]
# tensor: TemporalFusionTransformer/time_distributed_8/kernel (float32) [320, 4]
# [[ 0.13493241 -0.04352904  0.00635708  0.09954687]
#  [-0.01740202 -0.02418761  0.09894198 -0.12080048]
#  [-0.05947529 -0.08335155  0.06640922 -0.12183087]
#  ...
#  [-0.12936115  0.07595186 -0.10811354 -0.13456073]
#  [-0.10078001 -0.01615437 -0.02058702 -0.15055855]
#  [ 0.07853717  0.057817   -0.04225889  0.13047306]]
# tensor: TemporalFusionTransformer/time_distributed_9/bias (float32) [4]
# [ 0.00691015 -0.00468102 -0.00135876  0.00530969]
# tensor: TemporalFusionTransformer/time_distributed_9/kernel (float32) [320, 4]
# [[-0.06576664  0.02555074 -0.04122618 -0.05862449]
#  [ 0.0079126   0.02125954  0.08800602  0.10022157]
#  [ 0.12099122  0.08064644  0.16223735  0.01584766]
#  ...
#  [-0.12351291 -0.07309593 -0.03883353  0.07031193]
#  [-0.07462228  0.05733966 -0.08254954 -0.15053754]
#  [ 0.01495795  0.10286444  0.03212931  0.10021532]]
# # Total number of params: 10039723
# INFO:tensorflow:Restoring parameters from /content/long_range_TSF/tft_outputs/saved_models/traffic/fixed/TemporalFusionTransformer.ckpt
# Done.
# Computing best validation loss
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Validation loss is :  0.545636677812917
# Computing test loss
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# <class 'dict'>
# dict_keys(['p10', 'p50', 'p90', 'targets'])
# Training completed @ 2022-05-05 19:57:15.539456
# Best validation loss = 0.545636677812917
# Params:
# dropout_rate  =  0.3
# hidden_layer_size  =  320
# learning_rate  =  0.001
# max_gradient_norm  =  100.0
# minibatch_size  =  128
# model_folder  =  /content/long_range_TSF/tft_outputs/saved_models/traffic/fixed
# num_heads  =  4
# stack_size  =  1
# total_time_steps  =  192
# num_encoder_steps  =  168
# num_epochs  =  100
# early_stopping_patience  =  5
# multiprocessing_workers  =  6
# column_definition  =  [('id', <DataTypes.REAL_VALUED: 0>, <InputTypes.ID: 4>), ('hours_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.TIME: 5>), ('values', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('time_on_day', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('day_of_week', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('hours_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('categorical_id', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)]
# input_size  =  5
# output_size  =  1
# category_counts  =  [963]
# input_obs_loc  =  [0]
# static_input_loc  =  [4]
# known_regular_inputs  =  [1, 2, 3]
# known_categorical_inputs  =  [0]
#
# Normalised Quantile Loss for Test Data: P50=0.6682693712803996, P90=0.6918453008742408
